# %% [markdown]
# # Actividad - Trabajando con DataFrames de Pandas.
# ## Criterios de evaluación.
#
# * Se deben utilizar nombres de variables descriptivos y claros (Utilizar la nomeclatura correspondiente para los nombres de variables).
# * Comentarios claros y concisos que expliquen el propósito de cada sección del código.
# * Utilizar mensajes de commit **descriptivos**. (Puedes utilizar la extension CONVENTIONAL COMMIT de VS-CODE).
# * Entrega en tiempo y forma.
# * Todo el código desarrollado debe ser subido a un repositorio en GitHub (el nombre del repositorio de seguir la siguiente estructura: pandas_df_tlp3_nombre_apellido).
# * Para resolver las actividades se debe insertar casillas de codigo entre cada actividad del cuaderno de Jupyter
# * Deben trabajar con el datasets adjunto a la actividad
#
# ### ¡Importante!
# **El incumplimiento de los criterios de evaluación restará puntos en la nota final del práctico!**

# %%
import pandas as pd
import sqlite3

#Aqui agrega la conexión a la base de datos

conn = sqlite3.connect("Salaries.sqlite")

#Crea el dataframe con los datos del datasets
df = pd.read_sql_query("SELECT * FROM Salaries", conn)

conn.close()

# %% [markdown]
# 1. **Top 10 empleados con mayor salario total (incluyendo beneficios)**
# Extrae e imprime un top 10 de expleados con mayor salario incluyendo los beneficios

# %%
#todo
top_10_salario = df.sort_values(by="TotalPayBenefits", ascending=False).head(10)

top_10_salario = top_10_salario[["EmployeeName", "TotalPayBenefits"]]

print(top_10_salario)
# Out:
#                 EmployeeName  TotalPayBenefits
# 0             NATHANIEL FORD         567595.43
# 1               GARY JIMENEZ         538909.28
# 110531           David Shinn         510732.68
# 110532            Amy P Hart         479652.21
# 110533  William J Coaker Jr.         436224.36
# 72925         Gregory P Suhr         425815.28
# 72926   Joanne M Hayes-White         422353.40
# 110534        Gregory P Suhr         418019.22
# 110535  Joanne M Hayes-White         417435.10
# 110536       Ellen G Moffatt         415767.94

# %% [markdown]
# 2. **Filtrar empleados con más de 50,000 en horas extra, la columna a tratar es: (OvertimePay)**

# %%
#todo
#Eliminamos las filas con valores nulos en la columna OvertimePay, y los transformamos en enteros
#los convertimos en 0 si son nulos o no convertibles.
df["OvertimePay"] = pd.to_numeric(df["OvertimePay"], errors="coerce").fillna(0).astype(int)

#Mostramos los empleados que tienen más de 50 mil por hs extras.
df[df["OvertimePay"] > 50000 ]
# Out:
#             Id        EmployeeName                              JobTitle  \
# 1            2        GARY JIMENEZ       CAPTAIN III (POLICE DEPARTMENT)
# 2            3      ALBERT PARDINI       CAPTAIN III (POLICE DEPARTMENT)
# 3            4   CHRISTOPHER CHONG  WIRE ROPE CABLE MAINTENANCE MECHANIC
# 6            7           ALSON LEE    BATTALION CHIEF, (FIRE DEPARTMENT)
# 8            9      MICHAEL MORRIS    BATTALION CHIEF, (FIRE DEPARTMENT)
# ...        ...                 ...                                   ...
# 118288  118289    Francisco A Arce                      Transit Operator
# 118342  118343    Felix Pagatpatan                      Transit Operator
# 119450  119451         Bobby Jones              Track Maintenance Worker
# 119607  119608       Hung V Nguyen             Diagnostic Imaging Tech I
# 120204  120205  Girma-Worku Zeleke               Parking Control Officer
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# ...

# %% [markdown]
# 3. **Contar cuántos empleados únicos hay por año**

# %%
#todo
# utilizando .nunique() cuenta los valores únicos en la columna "EmployeeName" por cada año

empleados_unicos = df.groupby('Year')['EmployeeName'].nunique()

print("La cantidad de empleados únicos por año son: ")
print(empleados_unicos)
# Out:
# Cantidad de empleados únicos por año:
# Year
# 2011    33878
# 2012    34349
# 2013    36150
# 2014    36684
# Name: EmployeeName, dtype: int64

# %% [markdown]
# 4. **Ver cuántos cargos únicos (JobTitle) existen y los 5 más comunes**

# %%
#todo
#Filtramos para encon0trar los cargos únicos
cargos_unicos = df["JobTitle"].unique()
print("Cargos únicos: ")
print(cargos_unicos)


# Ahora buscamos los 5 más comunes. 

# Seleccionamos la columna "JobTitle" y contamos cuantas veces 
# aparece cada cargo usando value_counts()

cargos_mas_comunes = df["JobTitle"].value_counts().head(5)

print("\nLos cargos más comunes son: ")
print(cargos_mas_comunes)
# Out:
# Cargos únicos:
# ['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY'
#  'CAPTAIN III (POLICE DEPARTMENT)' 'WIRE ROPE CABLE MAINTENANCE MECHANIC'
#  ... 'Conversion' 'Cashier 3' 'Not provided']
#
# Cargos más comunes:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64

# %% [markdown]
# 5. **Mostrar el salario total (TotalPay) promedio por año**

# %%
#todo
# Agrupamos el salario por año, con el metodo mean obtenemos promedio y 
# con astype(int) lo convertimos a enteros.

salario_promedio_año = df.groupby("Year")["TotalPay"].mean().astype(int)

print("El salario promedio por año es: ")
print(salario_promedio_año)
# Out:
# Salario promedio por año:
# Year
# 2011    71744
# 2012    74113
# 2013    77611
# 2014    75463
# Name: TotalPay, dtype: int64

# %% [markdown]
# 6. **Exporta todos los datos a un CSV y muestra los ultimos 10 valores**

# %%
#todo

# Con el metodo to_csv() guardamos el dataframe en un archivo CSV.

df.to_csv("Salaries.csv", index=False)

#Con el metodo tail(10) mostramos las últimas 10 filas del dataframe
df.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle       BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant          0.00
# 148645  148646  Carolyn A Wilson     Human Services Technician          0.00
# 148646  148647      Not provided                  Not provided  Not Provided
# 148647  148648    Joann Anderson   Communications Dispatcher 2          0.00
# 148648  148649       Leon Walker                     Custodian          0.00
# 148649  148650     Roy I Tillery                     Custodian          0.00
# 148650  148651      Not provided                  Not provided  Not Provided
# 148651  148652      Not provided                  Not provided  Not Provided
# 148652  148653      Not provided                  Not provided  Not Provided
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch          0.00
#
#         OvertimePay      OtherPay      Benefits  TotalPay  TotalPayBenefits  \
# ...
